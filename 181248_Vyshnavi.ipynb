# %%
import pandas as pd

# %%
import os

import pandas as pd

import numpy as np 

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# %cd
# Out:
# C:\Users\MYPC

# %%
# %cd C:\Users\MYPC
# Out:
# C:\Users\MYPC

# %%
# %cd C:\Users\MYPC\Downloads
# Out:
# C:\Users\MYPC\Downloads

# %%
# %pwd
# Out:
# 'C:\\Users\\MYPC\\Downloads'

# %%
Movies=pd.read_csv('Movies.csv',sep=",")

# %%
Movies
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2    04-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4    04-Jan-13             Rajdhani Express           N     Drama
# 4       5    04-Jul-14                 Bobby Jasoos           N     Comedy
# 5       6    30-May-14                   Citylights          HS     Drama
# 6       7    19-Sep-14                Daawat-E-Ishq           N     Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N     Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW     Comedy
# 9      10    11-Jan-13                    Gangoobai           N     Drama
# 10     11    28-Mar-14                  Dishkiyaoon           N    Action
# 11     12    18-Jan-13                       Inkaar           N    Romance
# ...

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
# SlNo                   149 non-null int64
# Release Date           149 non-null object
# MovieName              149 non-null object
# ReleaseTime            149 non-null object
# Genre                  149 non-null object
# Budget                 149 non-null int64
# BoxOfficeCollection    149 non-null float64
# YoutubeViews           149 non-null int64
# YoutubeLikes           149 non-null int64
# YoutubeDislikes        149 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.7+ KB

# %%
Movies.info
# Out:
# <bound method DataFrame.info of      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2    04-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4    04-Jan-13             Rajdhani Express           N     Drama
# 4       5    04-Jul-14                 Bobby Jasoos           N     Comedy
# 5       6    30-May-14                   Citylights          HS     Drama
# 6       7    19-Sep-14                Daawat-E-Ishq           N     Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N     Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW     Comedy
# 9      10    11-Jan-13                    Gangoobai           N     Drama
# 10     11    28-Mar-14                  Dishkiyaoon           N    Action
# ...

# %%
Movies.shape
# Out:
# (149, 10)

# %%
Movies.head(5)
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2    04-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4    04-Jan-13    Rajdhani Express           N     Drama        7
# 4     5    04-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
Movies.tail(5)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
Movies.columns=Movies.columns.str.replace(' |-','_').str.lower()

# %%
Movies.columns
# Out:
# Index(['slno', 'release_date', 'moviename', 'releasetime', 'genre', 'budget',
#        'boxofficecollection', 'youtubeviews', 'youtubelikes',
#        'youtubedislikes', 'roi'],
#       dtype='object')

# %%
Movies.columns.value_counts()
# Out:
# genre                  1
# slno                   1
# roi                    1
# youtubelikes           1
# youtubeviews           1
# boxofficecollection    1
# budget                 1
# moviename              1
# release_date           1
# releasetime            1
# youtubedislikes        1
# dtype: int64

# %% [markdown]
# ### 1.a. 149 rows × 10 columns

# %% [markdown]
# ### 1.b.10

# %% [markdown]
# ### 1.c.Categorical 4,Numerical 5 int ,1 float and Total =6

# %% [markdown]
# ### 1.d. 2013,14,15 -  Total three years

# %%
Movies.sort_values('genre')
# Out:
#      slno release_date                             moviename releasetime  \
# 74     75    25-Apr-14                         Revolver Rani           N
# 25     26    08-Feb-13                            Special 26           N
# 26     27    24-Oct-14                        Happy New Year          LW
# 27     28    08-Feb-13             ABCD _ Any Body Can Dance           N
# 29     30    09-May-14                          Hawaa Hawaai          HS
# 89     90    19-Dec-14                                    PK          HS
# 86     87    28-Mar-14                           Youngistaan           N
# 81     82    28-Nov-14                                 Ungli           N
# 33     34    22-Feb-13                           Kai Po Che!           N
# 34     35    21-Feb-14                               Highway           N
# 76     77    17-May-13                             Aurangzeb           N
# 70     71    03-May-13                        Bombay Talkies           N
# ...

# %%
Movies.sort_values('genre', ascending=True).head(10)
# Out:
#     slno release_date                  moviename releasetime    genre  budget  \
# 74    75    25-Apr-14              Revolver Rani           N   Drama       24
# 25    26    08-Feb-13                 Special 26           N   Drama       42
# 26    27    24-Oct-14             Happy New Year          LW   Drama      125
# 27    28    08-Feb-13  ABCD _ Any Body Can Dance           N   Drama       12
# 29    30    09-May-14               Hawaa Hawaai          HS   Drama       11
# 89    90    19-Dec-14                         PK          HS   Drama       85
# 86    87    28-Mar-14                Youngistaan           N   Drama       26
# 81    82    28-Nov-14                      Ungli           N   Drama        5
# 33    34    22-Feb-13                Kai Po Che!           N   Drama       30
# 34    35    21-Feb-14                    Highway           N   Drama       30
#
#     boxofficecollection  youtubeviews  youtubelikes  youtubedislikes      roi
# ...

# %%
import re

# %%
Movies[['genre', 'moviename']].sort_values('genre', ascending = True)[0:5]
# Out:
#       genre                  moviename
# 74   Drama               Revolver Rani
# 25   Drama                  Special 26
# 26   Drama              Happy New Year
# 27   Drama   ABCD _ Any Body Can Dance
# 29   Drama                Hawaa Hawaai

# %%
Movies[['genre']].sort_values('genre', ascending = True).head(10)
# Out:
#       genre
# 74   Drama
# 25   Drama
# 26   Drama
# 27   Drama
# 29   Drama
# 89   Drama
# 86   Drama
# 81   Drama
# 33   Drama
# 34   Drama

# %% [markdown]
# ### 3

# %%
Movies['release_date']=pd.to_datetime(Movies['release_date'],errors='coerce')

# %%
Movies['release_date']
# Out:
# 0     2014-04-18
# 1     2013-01-04
# 2     2014-07-18
# 3     2013-01-04
# 4     2014-07-04
# 5     2014-05-30
# 6     2014-09-19
# 7     2013-01-11
# 8     2014-01-10
# 9     2013-01-11
# 10    2014-03-28
# 11    2013-01-18
# 12    2014-06-27
# 13    2013-01-18
# 14    2014-08-08
# 15    2013-01-18
# 16    2013-01-25
# 17    2014-06-06
# 18    2014-09-12
# 19    2014-06-13
# 20    2013-02-01
# 21    2014-03-07
# 22    2014-02-14
# 23    2014-10-02
# 24    2014-11-21
# 25    2013-02-08
# 26    2014-10-24
# 27    2013-02-08
# 28    2014-07-18
# 29    2014-05-09
#          ...
# 119   2013-11-01
# 120   2014-03-07
# 121   2013-11-08
# 122   2013-11-15
# 123   2013-11-22
# 124   2013-11-29
# 125   2013-10-11
# 126   2013-10-11
# 127   2013-10-16
# 128   2013-10-18
# 129   2013-10-25
# 130   2013-09-06
# 131   2013-09-06
# 132   2013-09-13
# 133   2014-05-16
# 134   2013-09-20
# 135   2013-09-20
# 136   2015-01-09
# 137   2015-01-16
# 138   2015-01-23
# 139   2015-01-30
# ...

# %%
Movies['omonth']=Movies['release_date'].dt.month

# %%
Movies['omonth']
# Out:
# 0       4
# 1       1
# 2       7
# 3       1
# 4       7
# 5       5
# 6       9
# 7       1
# 8       1
# 9       1
# 10      3
# 11      1
# 12      6
# 13      1
# 14      8
# 15      1
# 16      1
# 17      6
# 18      9
# 19      6
# 20      2
# 21      3
# 22      2
# 23     10
# 24     11
# 25      2
# 26     10
# 27      2
# 28      7
# 29      5
#        ..
# 119    11
# 120     3
# 121    11
# 122    11
# 123    11
# 124    11
# 125    10
# 126    10
# 127    10
# 128    10
# 129    10
# 130     9
# 131     9
# 132     9
# 133     5
# 134     9
# 135     9
# 136     1
# 137     1
# 138     1
# 139     1
# 140     1
# 141     2
# 142     2
# 143     2
# 144     2
# 145     3
# 146     3
# 147     3
# 148     5
# Name: omonth, Length: 149, dtype: int64

# %%
Movies['weekday']=Movies['release_date'].dt.weekday_name

# %%
Movies['weekday']
# Out:
# 0         Friday
# 1         Friday
# 2         Friday
# 3         Friday
# 4         Friday
# 5         Friday
# 6         Friday
# 7         Friday
# 8         Friday
# 9         Friday
# 10        Friday
# 11        Friday
# 12        Friday
# 13        Friday
# 14        Friday
# 15        Friday
# 16        Friday
# 17        Friday
# 18        Friday
# 19        Friday
# 20        Friday
# 21        Friday
# 22        Friday
# 23      Thursday
# 24        Friday
# 25        Friday
# 26        Friday
# 27        Friday
# 28        Friday
# 29        Friday
#          ...
# 119       Friday
# 120       Friday
# 121       Friday
# 122       Friday
# 123       Friday
# 124       Friday
# 125       Friday
# 126       Friday
# 127    Wednesday
# 128       Friday
# 129       Friday
# 130       Friday
# 131       Friday
# 132       Friday
# 133       Friday
# 134       Friday
# 135       Friday
# 136       Friday
# 137       Friday
# 138       Friday
# 139       Friday
# ...

# %%
Movies['year']=Movies['release_date'].dt.year

# %%
Movies['year']
# Out:
# 0      2014
# 1      2013
# 2      2014
# 3      2013
# 4      2014
# 5      2014
# 6      2014
# 7      2013
# 8      2014
# 9      2013
# 10     2014
# 11     2013
# 12     2014
# 13     2013
# 14     2014
# 15     2013
# 16     2013
# 17     2014
# 18     2014
# 19     2014
# 20     2013
# 21     2014
# 22     2014
# 23     2014
# 24     2014
# 25     2013
# 26     2014
# 27     2013
# 28     2014
# 29     2014
#        ...
# 119    2013
# 120    2014
# 121    2013
# 122    2013
# 123    2013
# 124    2013
# 125    2013
# 126    2013
# 127    2013
# 128    2013
# 129    2013
# 130    2013
# 131    2013
# 132    2013
# 133    2014
# 134    2013
# 135    2013
# 136    2015
# 137    2015
# 138    2015
# 139    2015
# 140    2015
# 141    2015
# 142    2015
# 143    2015
# 144    2015
# 145    2015
# 146    2015
# 147    2015
# 148    2014
# Name: year, Length: 149, dtype: int64

# %%
sns.countplot(x='moviename',data=Movies)  ## bars for movies

# %%
sns.barplot(x='moviename',y='omonth',data=Movies,ci=0) ## BArs by movienames and month  freq ..ci=0

# %%
sns.barplot(x='moviename',y='omonth',data=Movies) ### Movies by month in bars

# %%
sns.countplot(y='moviename',data=Movies)   ### Bars for movies

# %% [markdown]
# ### 4

# %%
sns.catplot(x='Budget', kind='box', data=Movies)

# %%
sns.catplot(y='Budget', kind='box', data=Movies)

# %% [markdown]
# ### 4.
# Q1=0,Q2=20,Q3=70 UL=150,LL=70
# Above 70 are outliers..L,H,M,MM -UL are High  and Mega Movies
# LL are Low and Medium movies..

# %%
sns.catplot(x='YoutubeLikes',y='Genre', kind='box', data=Movies)

# %% [markdown]
# ### 5 there are tiny boxes for all genres..Action and Romance has high boxes...That means Romance and Action has
# #### more Youtubelikes...and Action genre has extreme outliers..

# %% [markdown]
# ### 6

# %%
Movies['ROI']=Movies['BoxOfficeCollection']/Movies['Budget']

# %%
Movies['ROI']
# Out:
# 0      2.888889
# 1      1.200000
# 2      0.400000
# 3      0.050000
# 4      0.600000
# 5      5.000000
# 6      0.820000
# 7      1.212121
# 8      0.870968
# 9      0.005000
# 10     0.214286
# 11     2.050000
# 12     3.014286
# 13     0.450000
# 14     2.716667
# 15     0.022500
# 16     2.700000
# 17     0.600000
# 18     3.926667
# 19     1.260000
# 20     0.365000
# 21     0.529630
# 22     1.534000
# 23     2.875000
# 24     0.447917
# 25     2.452381
# 26     3.064000
# 27     3.666667
# 28     2.263333
# 29     0.909091
#          ...
# 119    2.608696
# 120    1.200000
# 121    0.073333
# 122    0.166667
# 123    0.421667
# 124    0.800000
# 125    0.535714
# 126    0.375000
# 127    0.900000
# 128    6.666667
# 129    0.545455
# 130    0.242667
# 131    2.200000
# 132    8.514286
# 133    1.833333
# 134    0.850000
# 135    8.500000
# 136    1.400000
# 137    1.388889
# 138    2.083333
# 139    1.210000
# 140    1.274545
# 141    0.950000
# 142    1.450000
# ...

# %%
Movies['ROI']=Movies['BoxOfficeCollection']*Movies['Budget']

# %%
Movies['ROI']
# Out:
# 0       3744.00
# 1        120.00
# 2         40.00
# 3          2.45
# 4        194.40
# 5        245.00
# 6        738.00
# 7       1320.00
# 8        837.00
# 9          0.02
# 10       168.00
# 11        51.25
# 12      3692.50
# 13         7.20
# 14      9780.00
# 15         0.36
# 16      9720.00
# 17        60.00
# 18       883.50
# 19       126.00
# 20        36.50
# 21       386.10
# 22      3835.00
# 23      1656.00
# 24      1032.00
# 25      4326.00
# 26     47875.00
# 27       528.00
# 28       325.92
# 29       110.00
#          ...
# 119    34500.00
# 120      120.00
# 121       16.50
# 122       24.00
# 123      379.50
# 124     2000.00
# 125      105.00
# 126        6.00
# 127     2250.00
# 128      240.00
# 129       66.00
# 130     1365.00
# 131     1375.00
# 132    10430.00
# 133      264.00
# 134     1360.00
# 135      850.00
# 136     2240.00
# 137      450.00
# 138     7500.00
# 139      756.25
# 140      154.22
# 141     1520.00
# 142     2320.00
# ...

# %%
sns.relplot(x='ROI',y='YoutubeLikes',data=Movies)

# %% [markdown]
# ### The data is more scattered in between 0 and 1000 and 0-20000 for Youtubelikes ...more on 0 is scattered data..some are scattered as extremities..
# ### means the ROi and youtubelikes are on 0-500 ROI  and data is mostly scattered in between 0-20000 for Youtubelikes..

# %%
sns.pairplot(data=Movies, hue="Budget")
# Out:
# C:\Users\MYPC\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\MYPC\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\MYPC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MYPC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(data=Movies) ### Correlation

# %%
sns.pairplot(data=Movies, size=2)
# Out:
# C:\Users\MYPC\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### 1. 10m
# ### Boxoffice collections ,Youtube view and You tube likes exhibits strong positive correlation...
# ### Strength is positive ,Direction is upward and Linearity  (Multicollinearity) functional form..(correlation)...Normally distributed...

# %% [markdown]
# ### 2. a. here y is Advertisements for FMCG and  Money- Budget for Movie production ..
# ### y=b0+b1x+e ,e= error
# ###  Indirect Advertising =Sales+Revenue+Money+Budget .....

# %% [markdown]
# ### 2.b . Yes it will be Multicollinearity means More number of collinearity...
# ### both Youtube likes and Youtube views causes Multicollinearity assumption in Regression.The remedie is PCA...
# ### These both youtube likes and views causes more causation..in collinearity..

# %% [markdown]
# ### 2.c. new possible variables are Sales.Promotions,Customers,CLTV,Customers retention,churn rate,Movie Collections,Direct Advertisements,Brand position....

# %% [markdown]
# ### 2.d. External variables are celebrity Endorsements ,Revenue,Customer priority ,Customers willing to pay ,4p's,Market strategy,Target Audience,Popularity of the brand ,Customer mind,Segmentation,Positioning.......
